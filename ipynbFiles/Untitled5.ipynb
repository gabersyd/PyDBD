# %%
import numpy as np
import sys

valuess=np.zeros((110,9),float)
file=open("ni.nscf2.txt.out")
for a in np.arange(1581):
    line=file.readline()
for b in np.arange(110):
    line=file.readline()
    lineSplit=line.split()
    valuess[b,:-1]=(lineSplit)
    line=file.readline()
    lineSplit=line.split()
    valuess[b,-1]=(lineSplit[-1])
    for r in np.arange(7):
        line=file.readline()
        
valuess
# Out:
# array([[ 4.4796, 11.551 , 11.6014, 11.6014, 12.658 , 12.658 , 37.0048,
#         39.5839, 40.6881],
#        [ 4.9889, 11.4073, 11.7055, 11.7159, 12.5552, 12.6897, 34.6155,
#         36.9361, 39.6619],
#        [ 6.1865, 11.185 , 11.7886, 11.8275, 12.5578, 12.8267, 29.548 ,
#         35.8403, 39.0526],
#        [ 7.7517, 11.215 , 11.6777, 11.7296, 12.8789, 13.1812, 24.7563,
#         35.2291, 37.9273],
#        [ 8.7989, 11.5268, 11.5952, 12.0567, 13.2508, 13.6304, 20.827 ,
#         35.0376, 37.1532],
#        [ 8.987 , 11.4731, 11.5622, 12.5563, 13.4196, 13.9392, 19.3846,
#         35.212 , 37.1328],
#        [ 8.5646, 11.5404, 11.6478, 11.6899, 13.2995, 13.3255, 21.9868,
#         35.6946, 36.6084],
#        [ 7.2304, 11.1329, 11.725 , 11.7829, 12.8141, 12.9911, 26.2861,
#         36.4356, 36.8005],
#        [ 5.7222, 11.2447, 11.797 , 11.8071, 12.529 , 12.7464, 31.2473,
#         37.2412, 37.5959],
#        [ 4.7361, 11.4616, 11.6677, 11.6711, 12.5728, 12.6954, 36.0757,
# ...
